# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import sqlite3

# %% [markdown]
# What is SQL :
#  ![image.png](attachment:image.png)

# %%
### connect to sqlite database
connection =sqlite3.connect("example.db")

# %%
cursor=connection.cursor()

# %%
## create a table 
cursor.execute('''
create Table if Not Exists employees(
    id Integer Primary key,
    name Text Not Null,
    age Integer,
    department text)
               ''')

# %%
## commit the changes 
connection.commit() 
cursor.execute('''
Select * from employees ''')

# %%
import sqlite3

# Use a context manager to ensure proper closing
with sqlite3.connect("example.db") as connection:
    cursor = connection.cursor()

    cursor.execute('''
    INSERT INTO employees(name, age, department)
    VALUES ('krish', 32, 'Data Scientist')
    ''')

    cursor.execute('''
    INSERT INTO employees(name, age, department)
    VALUES ('Bob', 25, 'Engineering')
    ''')

    cursor.execute('''
    INSERT INTO employees(name, age, department)
    VALUES ('charlie', 35, 'Finance')
    ''')

    connection.commit()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
## Querry the data from teh table 
cursor.execute('Select *  from employees')
rows=cursor.fetchall()

## print the quiried data 
for row in rows:
    print(row)
# Out:
# (1, 'krish', 34, 'Data Scientist')
# (2, 'Bob', 25, 'Engineering')
# (3, 'charlie', 35, 'Finance')
# (4, 'krish', 34, 'Data Scientist')
# (5, 'Bob', 25, 'Engineering')
# (6, 'charlie', 35, 'Finance')
# (7, 'krish', 32, 'Data Scientist')
# (8, 'Bob', 25, 'Engineering')
# (9, 'charlie', 35, 'Finance')

# %%
## update the data in the table
cursor.execute('''
update employees 
Set age=34
where name="krish"
'''
)
connection.commit()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
## Querry the data from teh table 
cursor.execute('Select *  from employees')
rows=cursor.fetchall()


## print the quiried data 
for row in rows:
    print(row)
# Out:
# (1, 'krish', 34, 'Data Scientist')
# (2, 'Bob', 25, 'Engineering')
# (3, 'charlie', 35, 'Finance')
# (4, 'krish', 34, 'Data Scientist')
# (5, 'Bob', 25, 'Engineering')
# (6, 'charlie', 35, 'Finance')
# (7, 'krish', 34, 'Data Scientist')
# (8, 'Bob', 25, 'Engineering')
# (9, 'charlie', 35, 'Finance')

# %%
cursor.execute('''
               
               delete from employees
               where name ='bob'
               ''')
connection.commit()

# %%
## Querry the data from teh table 
cursor.execute('Select *  from employees')
rows=cursor.fetchall()

## print the quiried data 
for row in rows:
    print(row)
# Out:
# (1, 'krish', 34, 'Data Scientist')
# (2, 'Bob', 25, 'Engineering')
# (3, 'charlie', 35, 'Finance')
# (4, 'krish', 34, 'Data Scientist')
# (5, 'Bob', 25, 'Engineering')
# (6, 'charlie', 35, 'Finance')
# (7, 'krish', 34, 'Data Scientist')
# (8, 'Bob', 25, 'Engineering')
# (9, 'charlie', 35, 'Finance')

# %%
## working with sales data
# connection to sqlite database
connection=sqlite3.connect('sales_data.db')
cursor=connection.cursor()
# create a table for sales data 
cursor.execute('''
               Create table if not exists sales(
               id Integer primary key AUTOINCREMENT,
               date text not NULL,
               product text Not Null,
               sales integer,
               region text 
               )
               ''')
sales_data=[
    ('2023-01-01','Product1',100,'North'),
    ('2023-01-02','Product2',200,'South'),
    ('2023-01-03','Product3',250,'West'),
    ('2023-01-05','product2',300,'North')
]
connection.commit()

# %%
cursor.executemany('''
Insert into sales(date,product,sales,region)
                   values(?,?,?,?)
''',sales_data)
connection.commit()

# %%
## Querry the data from teh table 
cursor.execute('Select *  from sales')
rows=cursor.fetchall()

## print the quiried data 
for row in rows:
    print(row)
# Out:
# (1, '2023-01-01', 'Product1', 100, 'North')
# (2, '2023-01-02', 'Product2', 200, 'South')
# (3, '2023-01-03', 'Product3', 250, 'West')
# (4, '2023-01-05', 'product2', 300, 'North')
# (5, '2023-01-01', 'Product1', 100, 'North')
# (6, '2023-01-02', 'Product2', 200, 'South')
# (7, '2023-01-03', 'Product3', 250, 'West')
# (8, '2023-01-05', 'product2', 300, 'North')
