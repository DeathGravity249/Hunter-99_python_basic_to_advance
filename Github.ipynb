# %% [markdown]
# Here is everything is correct but the command that says git checkout -b shadow is creating a branch but you don't need to do this as you already have just switch it to commit the work and then again come to main branch and then merge and write the final command git push origin shadow :
# ![image.png](attachment:image.png)
