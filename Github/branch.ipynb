# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 1. Ensure shadow branch is ready
# git checkout shadow
# git add .
# git commit -m "Final changes from shadow branch"
#
# # 2. Update local main
# git checkout main
# git pull origin main
#
# # 3. Merge and push
# git merge shadow
# git push origin main

# %% [markdown]
# # Delete local shadow branch
# git branch -d shadow
#
# # Delete remote shadow branch (if you pushed it)
# git push origin --delete shadow

# %% [markdown]
# Today i encountered a problem as my file got deleted why uploding to shadow
# the following command help to recover it
# ![image.png](attachment:image.png)
