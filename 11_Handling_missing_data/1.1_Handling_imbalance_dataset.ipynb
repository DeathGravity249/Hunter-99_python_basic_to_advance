# %% [markdown]
# ## Handling Imbalanced datset
#
# Suppose we have data set thousand  yes and hundered no :
# Up sampling ->increasing the hundred one
# Down sampling ->decreasing the 900

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
import pandas as pd

# SEt the random seed for reproducibility 
np.random.seed(123)

## Create a datframe with two classess
n_samples=1000
class_0_ratio=0.9
n_class_0=int(n_samples*class_0_ratio)
n_class_1=n_samples-n_class_0

# %%
n_class_0,n_class_1
# Out:
# (900, 100)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
## create my datframe with imbalanced datset
class_0=pd.DataFrame({

    "feature_1": np.random.normal(loc=0 ,scale =1 ,size=n_class_0),
    "feature_2": np.random.normal(loc=0,scale=1,size=n_class_0),
    "target":[0]*n_class_0
})

class_1=pd.DataFrame({
    "feature_1":np.random.normal(loc=2,scale=1,size=n_class_1),
    "feature_2":np.random.normal(loc=2,scale=1,size=n_class_1),
    "target" : [1]*n_class_1

})

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df=pd.concat([class_0,class_1]).reset_index(drop=True)

# %%
df.head()
# Out:
#    feature_1  feature_2  target
# 0  -1.085631   0.551302       0
# 1   0.997345   0.419589       0
# 2   0.282978   1.815652       0
# 3  -1.506295  -0.252750       0
# 4  -0.578600  -0.292004       0

# %%
df["target"].value_counts()
# Out:
# target
# 0    900
# 1    100
# Name: count, dtype: int64
