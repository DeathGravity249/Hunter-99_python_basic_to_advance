# %%
import math
math.sqrt(14)
# Out:
# 3.7416573867739413

# %%
from math import sqrt,pi
print(sqrt(8))
print(sqrt(25))
print(pi)
# Out:
# 2.8284271247461903
# 5.0
# 3.141592653589793

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np #->alias->nickname
np.array([1,2,3,4])
# Out:
# array([1, 2, 3, 4])

# %%
from math import * ## *->all function
print(pi)
# Out:
# 3.141592653589793

# %%
from package.maths import addition
addition(2,3)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from package.maths import addition
#       2 addition(2,3)
#
# ModuleNotFoundError: No module named 'package'
