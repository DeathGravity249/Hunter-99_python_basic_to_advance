# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# This is how flask skeleton is working :
# ![image.png](attachment:image.png)

# %% [markdown]
# The basic idea behing the app :
# ![image.png](attachment:image.png)

# %% [markdown]
# The meaning behind the parameter when we pass it :
# ![image.png](attachment:image.png)

# %% [markdown]
# what is jinja 2 template and why it is used :
# ![image.png](attachment:image.png)
