# %%
import pandas as pd

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Series 
import pandas as pd 
data=[1,2,3,4,5]
series =pd.Series(data)
print(series)
print(type(series))
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
# <class 'pandas.core.series.Series'>

# %%
# creating series from the dictionary
# dictionary key value pairs , 1 ->key, 2->value
data={"Ayush":1,"Krish":12,"Mohini":23}
pd.Series(data)
# Out:
# Ayush      1
# Krish     12
# Mohini    23
# dtype: int64

# %%
data=[11,22,44,55]
indx=["a","b","c","d"]
z=pd.Series(data,index=indx)
print(z['a'])
# Out:
# 11

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
## Datframe
## create a datafrom dictionary

data={
    "Name":["Ayush","Krish","Madhav"],
    "Age":[12,33,42],
    "City":["Banglore","New York","Florida"]
    
      }
df=pd.DataFrame(data)
print(df)
print(type(df))
# Out:
#      Name  Age      City
# 0   Ayush   12  Banglore
# 1   Krish   33  New York
# 2  Madhav   42   Florida
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
np.array(df)
# Out:
# array([['Ayush', 12, 'Banglore'],
#        ['Krish', 33, 'New York'],
#        ['Madhav', 42, 'Florida']], dtype=object)

# %%
import shutil as sl

sl.copy(r"D:\Download\username-password-recovery-code.csv", 
        r"C:\Users\Death Gravity\OneDrive\Desktop\Hunter\04_Data_Analysis_Python\Online_data.csv")
# Out:
# 'C:\\Users\\Death Gravity\\OneDrive\\Desktop\\Hunter\\04_Data_Analysis_Python\\Online_data.csv'

# %%
df =pd.read_csv("Online_data.csv")
print(df)
print("This is recquired output")
print(df.head(2))
# Out:
#   Username; Identifier;One-time password;Recovery code;First name;Last name;Department;Location
# 0  booker12;9012;12se74;rb9012;Rachel;Booker;Sale...
# 1  grey07;2070;04ap67;lg2070;Laura;Grey;Depot;London
# 2  johnson81;4081;30no86;cj4081;Craig;Johnson;Dep...
# 3  jenkins46;9346;14ju73;mj9346;Mary;Jenkins;Engi...
# 4  smith79;5079;09ja61;js5079;Jamie;Smith;Enginee...
# This is recquired output
#   Username; Identifier;One-time password;Recovery code;First name;Last name;Department;Location
# 0  booker12;9012;12se74;rb9012;Rachel;Booker;Sale...
# 1  grey07;2070;04ap67;lg2070;Laura;Grey;Depot;London

# %%
df.tail(2)
# Out:
#   Username; Identifier;One-time password;Recovery code;First name;Last name;Department;Location
# 3  jenkins46;9346;14ju73;mj9346;Mary;Jenkins;Engi...
# 4  smith79;5079;09ja61;js5079;Jamie;Smith;Enginee...

# %%
data
# Out:
# {'Name': ['Ayush', 'Krish', 'Madhav'],
#  'Age': [12, 33, 42],
#  'City': ['Banglore', 'New York', 'Florida']}

# %%
## Datframe
## create a datafrom dictionary

data={
    "Name":["Ayush","Krish","Madhav"],
    "Age":[12,33,42],
    "City":["Banglore","New York","Florida"]
    
      }
df=pd.DataFrame(data)
print(df)
print(type(df))
# Out:
#      Name  Age      City
# 0   Ayush   12  Banglore
# 1   Krish   33  New York
# 2  Madhav   42   Florida
# <class 'pandas.core.frame.DataFrame'>

# %%
df["Name"]
# Out:
# 0     Ayush
# 1     Krish
# 2    Madhav
# Name: Name, dtype: object

# %%
df.loc[0] # going with row index
# Out:
# Name       Ayush
# Age           12
# City    Banglore
# Name: 0, dtype: object

# %%
df.iloc[0][0]
# Out:
# C:\Users\Death Gravity\AppData\Local\Temp\ipykernel_21000\2900375399.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.iloc[0][0]
# 'Ayush'

# %% [markdown]
# Mock Q for better understanding

# %%
import pandas as pd

# Create sample DataFrame
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David'],
    'Age': [24, 30, 22, 28],
    'City': ['Delhi', 'Mumbai', 'Chennai', 'Bangalore']
}

df = pd.DataFrame(data, index=['a', 'b', 'c', 'd'])

print(df)
# Out:
#       Name  Age       City
# a    Alice   24      Delhi
# b      Bob   30     Mumbai
# c  Charlie   22    Chennai
# d    David   28  Bangalore

# %%
df.loc['c']
# Out:
# Name    Charlie
# Age          22
# City    Chennai
# Name: c, dtype: object

# %%
df.iloc[1][2]
# Out:
# C:\Users\Death Gravity\AppData\Local\Temp\ipykernel_21000\65333983.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.iloc[1][2]
# 'Mumbai'

# %%
df.loc['d','Age':]
# Out:
# Age            28
# City    Bangalore
# Name: d, dtype: object

# %%
df.iloc[0:2]
# Out:
#     Name  Age    City
# a  Alice   24   Delhi
# b    Bob   30  Mumbai

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df.loc[:,"Name"]
# Out:
# a      Alice
# b        Bob
# c    Charlie
# d      David
# Name: Name, dtype: object

# %%
print("This was earlier ")
# Out:
# This was earlier

# %%
df.loc['a':'d',"Name"]
# Out:
# a      Alice
# b        Bob
# c    Charlie
# d      David
# Name: Name, dtype: object

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
## Accessing specified element
df["Name"]
# Out:
# a      Alice
# b        Bob
# c    Charlie
# d      David
# Name: Name, dtype: object

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print(df.loc["a":"d","Name"])
# Out:
# a      Alice
# b        Bob
# c    Charlie
# d      David
# Name: Name, dtype: object

# %%
## accessing a specific element
df.at['b',"Name"]
# Out:
# 'Bob'

# %%
## Accessing a specified element using iat
df.iat[2,2]
# Out:
# 'Chennai'

# %%
import pandas as pd

# Create sample DataFrame
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David'],
    'Age': [24, 30, 22, 28],
    'City': ['Delhi', 'Mumbai', 'Chennai', 'Bangalore']
}

df = pd.DataFrame(data, index=['a', 'b', 'c', 'd'])

print(df)
# Out:
#       Name  Age       City
# a    Alice   24      Delhi
# b      Bob   30     Mumbai
# c  Charlie   22    Chennai
# d    David   28  Bangalore

# %%
## Data manuplulation with data frame
df['Salary']=[50000,60000,70000,90000]
print(df)
# Out:
#       Name  Age       City  Salary
# a    Alice   24      Delhi   50000
# b      Bob   30     Mumbai   60000
# c  Charlie   22    Chennai   70000
# d    David   28  Bangalore   90000

# %%
df.drop("Salary",axis=1,inplace=True) # does not permanently

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df
# Out:
#       Name  Age       City
# a    Alice   24      Delhi
# b      Bob   30     Mumbai
# c  Charlie   22    Chennai
# d    David   28  Bangalore

# %%
## add agae t the column
df["Age"]=df["Age"]+1

# %%
df
# Out:
#       Name  Age       City
# a    Alice   25      Delhi
# b      Bob   31     Mumbai
# c  Charlie   23    Chennai
# d    David   29  Bangalore

# %%
df.drop('a')
# Out:
#       Name  Age       City
# b      Bob   31     Mumbai
# c  Charlie   23    Chennai
# d    David   29  Bangalore

# %%
df.drop("A" \
"ge",axis=1)
# Out:
#       Name       City
# a    Alice      Delhi
# b      Bob     Mumbai
# c  Charlie    Chennai
# d    David  Bangalore

# %%
import pandas as pd

# Create sample DataFrame
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David'],
    'Age': [24, 30, 22, 28],
    'City': ['Delhi', 'Mumbai', 'Chennai', 'Bangalore']
}

df = pd.DataFrame(data, index=['a', 'b', 'c', 'd'])

print(df)
# Out:
#       Name  Age       City
# a    Alice   24      Delhi
# b      Bob   30     Mumbai
# c  Charlie   22    Chennai
# d    David   28  Bangalore

# %%
df.describe()
# Out:
#              Age
# count   4.000000
# mean   26.000000
# std     3.651484
# min    22.000000
# 25%    23.500000
# 50%    26.000000
# 75%    28.500000
# max    30.000000
