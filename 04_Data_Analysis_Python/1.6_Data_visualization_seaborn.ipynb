# %%
import seaborn as sns

# %%
# Basci plotting with seaborn
tips=sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# create a scatter plot
import matplotlib.pyplot as plt
sns.scatterplot(x="total_bill",y='tip',data=tips)
plt.title("Scatter data set ")
plt.grid(True)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
sns.scatterplot(
    x="total_bill",
    y="tip",
    data=tips,
    hue="sex",       # color by gender
    style="smoker",  # marker style by smoker status
    size="size",     # point size by party size
    palette="dark"
)
plt.title("Advanced Scatter Plot: Tips")
plt.grid(True)
plt.show()

# %% [markdown]
# The thing smoker is doing as follows:
# ![image.png](attachment:image.png)

# %% [markdown]
# The thing size is doing as follows :
# ![image.png](attachment:image.png)

# %% [markdown]
# Manually assigning palette color syntax:
# ![image.png](attachment:image.png)

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# lineplot
sns.lineplot(x='size',y='total_bill',data=tips)
plt.title("line plot of total bill by size ")
plt.grid(True)
plt.show()

# %%
## categorical plot
# BAR plot
sns.barplot(x='day',y='total_bill',data=tips)
plt.show()

# %%
## Box plot
sns.boxplot(x='day',y='total_bill',data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
## Violin Plot
sns.violinplot(x="day",y='total_bill',data=tips)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
## Histogram
sns.histplot(tips['total_bill'],bins=10,kde=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
## KDE plot
sns.kdeplot(tips['total_bill'],fill=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
## Pairplot
sns.pairplot(tips)

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
## Heatmap
corr=tips[['total_bill','tip','size']].corr()
corr
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(corr,annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The data we are taking is exist as data frame:
# ![image.png](attachment:image.png)

# %%
import pandas as pd
sales_df=pd.read_csv("Sales_data.csv")

# %%
sales_df.head()
# Out:
#          Date   Product Region  Units Sold  Unit Price  Revenue  Discount (%)  \
# 0  2024-01-01  Widget A  North          10          25      250             5
# 1  2024-01-01  Widget B  South           5          30      150             0
# 2  2024-01-02  Widget A   East           7          25      175            10
# 3  2024-01-02  Widget C   West           3          40      120             0
# 4  2024-01-03  Widget B  North           8          30      240             5
#
#    Salesperson
# 0     John Doe
# 1   Jane Smith
# 2     John Doe
# 3  Emily Clark
# 4   Jane Smith

# %%
## Plot total sales by product
plt.figure(figsize=(10,6))
sns.barplot(x="Region",y="Revenue",data=sales_df,estimator=sum)
# Out:
# <Axes: xlabel='Region', ylabel='Revenue'>
