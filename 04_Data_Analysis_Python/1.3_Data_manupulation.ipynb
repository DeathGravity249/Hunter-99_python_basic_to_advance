# %%
import pandas as pd

# Load the CSV file
df = pd.read_csv("student_id.csv")

# Now you can try pandas operations, for example:
print(df.head())

print(df[df['Grade'] == 'A+'])
# Out:
#    StudentID     Name  Math  Physics  Chemistry Grade
# 0          1    Alice  85.0       78       92.0     A
# 1          2      Bob  75.0       88       85.0     B
# 2          3  Charlie  90.0       92       88.0     A
# 3          4    David  60.0       65        NaN   NaN
# 4          5      Eva  95.0       98       99.0    A+
#    StudentID  Name  Math  Physics  Chemistry Grade
# 4          5   Eva  95.0       98       99.0    A+
# 9         10  Jane  92.0       95       94.0    A+

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print(df.describe())
# Out:
#        StudentID       Math    Physics  Chemistry
# count   10.00000   9.000000  10.000000   9.000000
# mean     5.50000  81.666667  82.100000  83.666667
# std      3.02765  11.500000  13.395273  12.459936
# min      1.00000  60.000000  58.000000  60.000000
# 25%      3.25000  75.000000  73.500000  82.000000
# 50%      5.50000  85.000000  86.500000  85.000000
# 75%      7.75000  90.000000  91.500000  92.000000
# max     10.00000  95.000000  98.000000  99.000000

# %%
print(df["Math"].describe())
# Out:
# count     9.000000
# mean     81.666667
# std      11.500000
# min      60.000000
# 25%      75.000000
# 50%      85.000000
# 75%      90.000000
# max      95.000000
# Name: Math, dtype: float64

# %%
print(df)
# Out:
#    StudentID     Name  Math  Physics  Chemistry Grade
# 0          1    Alice  85.0       78       92.0     A
# 1          2      Bob  75.0       88       85.0     B
# 2          3  Charlie  90.0       92       88.0     A
# 3          4    David  60.0       65        NaN   NaN
# 4          5      Eva  95.0       98       99.0    A+
# 5          6    Frank   NaN       58       60.0     D
# 6          7    Grace  80.0       85       82.0     B
# 7          8    Helen  70.0       72       68.0     C
# 8          9      Ian  88.0       90       85.0    B+
# 9         10     Jane  92.0       95       94.0    A+

# %%
print(df[df["Grade"]=="A+"])
# Out:
#    StudentID  Name  Math  Physics  Chemistry Grade
# 4          5   Eva  95.0       98       99.0    A+
# 9         10  Jane  92.0       95       94.0    A+

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df.describe()
# Out:
#        StudentID       Math    Physics  Chemistry
# count   10.00000   9.000000  10.000000   9.000000
# mean     5.50000  81.666667  82.100000  83.666667
# std      3.02765  11.500000  13.395273  12.459936
# min      1.00000  60.000000  58.000000  60.000000
# 25%      3.25000  75.000000  73.500000  82.000000
# 50%      5.50000  85.000000  86.500000  85.000000
# 75%      7.75000  90.000000  91.500000  92.000000
# max     10.00000  95.000000  98.000000  99.000000

# %%
df.dtypes
# Out:
# StudentID      int64
# Name          object
# Math         float64
# Physics        int64
# Chemistry    float64
# Grade         object
# dtype: object

# %%
## Handling Missing values
## it tells wheter teh files has something is missing
df.isnull()
# Out:
#    StudentID   Name   Math  Physics  Chemistry  Grade
# 0      False  False  False    False      False  False
# 1      False  False  False    False      False  False
# 2      False  False  False    False      False  False
# 3      False  False  False    False       True   True
# 4      False  False  False    False      False  False
# 5      False  False   True    False      False  False
# 6      False  False  False    False      False  False
# 7      False  False  False    False      False  False
# 8      False  False  False    False      False  False
# 9      False  False  False    False      False  False

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df.isnull().any(axis=1)
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5     True
# 6    False
# 7    False
# 8    False
# 9    False
# dtype: bool

# %%
df.isnull().any()
# Out:
# StudentID    False
# Name         False
# Math          True
# Physics      False
# Chemistry     True
# Grade         True
# dtype: bool

# %%
df.isnull().sum()
# Out:
# StudentID    0
# Name         0
# Math         1
# Physics      0
# Chemistry    1
# Grade        1
# dtype: int64

# %%
df_filled=df.fillna("0")
## Fill everywhere where it is False with with specified value
print(df_filled)
# Out:
#    StudentID     Name  Math  Physics Chemistry Grade
# 0          1    Alice  85.0       78      92.0     A
# 1          2      Bob  75.0       88      85.0     B
# 2          3  Charlie  90.0       92      88.0     A
# 3          4    David  60.0       65         0     0
# 4          5      Eva  95.0       98      99.0    A+
# 5          6    Frank     0       58      60.0     D
# 6          7    Grace  80.0       85      82.0     B
# 7          8    Helen  70.0       72      68.0     C
# 8          9      Ian  88.0       90      85.0    B+
# 9         10     Jane  92.0       95      94.0    A+

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
## Filling missing values with the mean of the column
df['Maths_fillna']=df['Math'].fillna(df['Math'].mean())

# %%
print(df)
# Out:
#    StudentID     Name  Math  Physics  Chemistry Grade  Maths_fillna
# 0          1    Alice  85.0       78       92.0     A     85.000000
# 1          2      Bob  75.0       88       85.0     B     75.000000
# 2          3  Charlie  90.0       92       88.0     A     90.000000
# 3          4    David  60.0       65        NaN   NaN     60.000000
# 4          5      Eva  95.0       98       99.0    A+     95.000000
# 5          6    Frank   NaN       58       60.0     D     81.666667
# 6          7    Grace  80.0       85       82.0     B     80.000000
# 7          8    Helen  70.0       72       68.0     C     70.000000
# 8          9      Ian  88.0       90       85.0    B+     88.000000
# 9         10     Jane  92.0       95       94.0    A+     92.000000

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df.dtypes
# Out:
# StudentID         int64
# Name             object
# Math            float64
# Physics           int64
# Chemistry       float64
# Grade            object
# Maths_fillna    float64
# dtype: object

# %%
## Rename column
df.rename(columns={"Chemistry":"Python"})
# Out:
#    StudentID     Name  Math  Physics  Python Grade  Maths_fillna
# 0          1    Alice  85.0       78    92.0     A     85.000000
# 1          2      Bob  75.0       88    85.0     B     75.000000
# 2          3  Charlie  90.0       92    88.0     A     90.000000
# 3          4    David  60.0       65     NaN   NaN     60.000000
# 4          5      Eva  95.0       98    99.0    A+     95.000000
# 5          6    Frank   NaN       58    60.0     D     81.666667
# 6          7    Grace  80.0       85    82.0     B     80.000000
# 7          8    Helen  70.0       72    68.0     C     70.000000
# 8          9      Ian  88.0       90    85.0    B+     88.000000
# 9         10     Jane  92.0       95    94.0    A+     92.000000

# %%
df
# Out:
#    StudentID     Name  Math  Physics  Chemistry Grade  Maths_fillna
# 0          1    Alice  85.0       78       92.0     A     85.000000
# 1          2      Bob  75.0       88       85.0     B     75.000000
# 2          3  Charlie  90.0       92       88.0     A     90.000000
# 3          4    David  60.0       65        NaN   NaN     60.000000
# 4          5      Eva  95.0       98       99.0    A+     95.000000
# 5          6    Frank   NaN       58       60.0     D     81.666667
# 6          7    Grace  80.0       85       82.0     B     80.000000
# 7          8    Helen  70.0       72       68.0     C     70.000000
# 8          9      Ian  88.0       90       85.0    B+     88.000000
# 9         10     Jane  92.0       95       94.0    A+     92.000000

# %%
## change datatypes
df2=df["Physics_new"]=df["Physics"].astype(float)

# %%
df['value_new']=df["Chemistry"].fillna(df["Chemistry"].mean()).astype(int)

# %%
df
# Out:
#    StudentID     Name  Math  Physics  Chemistry Grade  Maths_fillna  \
# 0          1    Alice  85.0       78       92.0     A     85.000000
# 1          2      Bob  75.0       88       85.0     B     75.000000
# 2          3  Charlie  90.0       92       88.0     A     90.000000
# 3          4    David  60.0       65        NaN   NaN     60.000000
# 4          5      Eva  95.0       98       99.0    A+     95.000000
# 5          6    Frank   NaN       58       60.0     D     81.666667
# 6          7    Grace  80.0       85       82.0     B     80.000000
# 7          8    Helen  70.0       72       68.0     C     70.000000
# 8          9      Ian  88.0       90       85.0    B+     88.000000
# 9         10     Jane  92.0       95       94.0    A+     92.000000
#
#    Physics_new  value_new
# 0         78.0         92
# 1         88.0         85
# 2         92.0         88
# 3         65.0         83
# 4         98.0         99
# 5         58.0         60
# 6         85.0         82
# ...

# %%
df["New_value"]=df["Physics"].apply(lambda x: x**2)

# %%
## Here added new column and filled it with pysics square value
df
# Out:
#    StudentID     Name  Math  Physics  Chemistry Grade  Maths_fillna  \
# 0          1    Alice  85.0       78       92.0     A     85.000000
# 1          2      Bob  75.0       88       85.0     B     75.000000
# 2          3  Charlie  90.0       92       88.0     A     90.000000
# 3          4    David  60.0       65        NaN   NaN     60.000000
# 4          5      Eva  95.0       98       99.0    A+     95.000000
# 5          6    Frank   NaN       58       60.0     D     81.666667
# 6          7    Grace  80.0       85       82.0     B     80.000000
# 7          8    Helen  70.0       72       68.0     C     70.000000
# 8          9      Ian  88.0       90       85.0    B+     88.000000
# 9         10     Jane  92.0       95       94.0    A+     92.000000
#
#    Physics_new  value_new  New_value
# 0         78.0         92       6084
# 1         88.0         85       7744
# 2         92.0         88       8464
# 3         65.0         83       4225
# ...

# %%
# Data Aggregating and Grouping
df.head()
# Out:
#    StudentID     Name  Math  Physics  Chemistry Grade  Maths_fillna  \
# 0          1    Alice  85.0       78       92.0     A          85.0
# 1          2      Bob  75.0       88       85.0     B          75.0
# 2          3  Charlie  90.0       92       88.0     A          90.0
# 3          4    David  60.0       65        NaN   NaN          60.0
# 4          5      Eva  95.0       98       99.0    A+          95.0
#
#    Physics_new  value_new  New_value
# 0         78.0         92       6084
# 1         88.0         85       7744
# 2         92.0         88       8464
# 3         65.0         83       4225
# 4         98.0         99       9604

# %%
import pandas as pd

dff=pd.read_csv("Employe.csv")

# %%
dff
# Out:
#    EmployeeID           Name   Department   Salary  Experience  \
# 0         101     John Smith  Engineering  75000.0         5.0
# 1         102  Alice Johnson    Marketing      NaN         3.0
# 2         103        Bob Lee  Engineering  82000.0         6.0
# 3         104       Lisa Ray        Sales  68000.0         NaN
# 4         105      Tom Hardy          NaN  72000.0         4.0
# 5         106    Sarah Green    Marketing  79000.0         5.0
# 6         107    Michael Tan  Engineering  84000.0         7.0
# 7         108    Emily White        Sales  66000.0         2.0
#
#    ProjectsCompleted  PerformanceScore  OvertimeHours
# 0                 12                88             10
# 1                  9                79              5
# 2                 15                92              8
# 3                 10                85             12
# 4                 11                74              7
# 5                 13                90              9
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
dff
# Out:
#    EmployeeID           Name   Department   Salary  Experience  \
# 0         101     John Smith  Engineering  75000.0         5.0
# 1         102  Alice Johnson    Marketing      NaN         3.0
# 2         103        Bob Lee  Engineering  82000.0         6.0
# 3         104       Lisa Ray        Sales  68000.0         NaN
# 4         105      Tom Hardy          NaN  72000.0         4.0
# 5         106    Sarah Green    Marketing  79000.0         5.0
# 6         107    Michael Tan  Engineering  84000.0         7.0
# 7         108    Emily White        Sales  66000.0         2.0
#
#    ProjectsCompleted  PerformanceScore  OvertimeHours
# 0                 12                88             10
# 1                  9                79              5
# 2                 15                92              8
# 3                 10                85             12
# 4                 11                74              7
# 5                 13                90              9
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
dff
# Out:
#    EmployeeID           Name   Department   Salary  Experience  \
# 0         101     John Smith  Engineering  75000.0         5.0
# 1         102  Alice Johnson    Marketing      NaN         3.0
# 2         103        Bob Lee  Engineering  82000.0         6.0
# 3         104       Lisa Ray        Sales  68000.0         NaN
# 4         105      Tom Hardy          NaN  72000.0         4.0
# 5         106    Sarah Green    Marketing  79000.0         5.0
# 6         107    Michael Tan  Engineering  84000.0         7.0
# 7         108    Emily White        Sales  66000.0         2.0
#
#    ProjectsCompleted  PerformanceScore  OvertimeHours
# 0                 12                88             10
# 1                  9                79              5
# 2                 15                92              8
# 3                 10                85             12
# 4                 11                74              7
# 5                 13                90              9
# ...

# %%
grouped_sum=dff.groupby(["Name","Department"])["PerformanceScore"].sum()

# %%
grouped_sum
# Out:
# Name           Department
# Alice Johnson  Marketing      79
# Bob Lee        Engineering    92
# Emily White    Sales          70
# John Smith     Engineering    88
# Lisa Ray       Sales          85
# Michael Tan    Engineering    95
# Sarah Green    Marketing      90
# Name: PerformanceScore, dtype: int64

# %%
# Merging and joining Dataframes
# Create sample Dataframes
df1=pd.DataFrame({"key":["A","B","C"],"Value":[1,2,3]})
df2=pd.DataFrame({"key":["A","B","C"],"Value":[4,5,6]})

# %%
d={"key":["a","b","c"],"value":[2,33,5]}
print(d)
print(d["key"])
# Out:
# {'key': ['a', 'b', 'c'], 'value': [2, 33, 5]}
# ['a', 'b', 'c']

# %%
df1
# Out:
#   key  Value
# 0   A      1
# 1   B      2
# 2   C      3

# %%
df2
# Out:
#   key  Value
# 0   A      4
# 1   B      5
# 2   C      6

# %%
# Create sample Dataframes
df1=pd.DataFrame({"key":["A","B","C"],"Value":[1,2,3]})
df2=pd.DataFrame({"key":["A","B","D"],"Value":[4,5,6]})

# %%
## merge data frame
# first one are the data frames
# then we apply on which column 
# Then there is how the joint should happen 
pd.merge(df1,df2,on="key",how="inner")
# Out:
#   key  Value_x  Value_y
# 0   A        1        4
# 1   B        2        5

# %%
pd.merge(df1,df2,on="key",how="outer")
# Out:
#   key  Value_x  Value_y
# 0   A      1.0      4.0
# 1   B      2.0      5.0
# 2   C      3.0      NaN
# 3   D      NaN      6.0

# %% [markdown]
# ![image.png](attachment:image.png)
