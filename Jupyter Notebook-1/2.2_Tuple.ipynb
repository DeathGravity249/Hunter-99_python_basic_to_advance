# %% [markdown]
# Tuple are different from the list as they are not mutable or immutable

# %%
empty_tuple =()
print(empty_tuple)
print(type(empty_tuple))
# Out:
# ()
# <class 'tuple'>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
lst=list()
print(type(lst))
tple=tuple()
print(type(tple))
# Out:
# <class 'list'>
# <class 'tuple'>

# %% [markdown]
# Here you are creating a tuple from a list [1, 2, 3].
#
# The tuple() function converts the list into a tuple (1, 2, 3).
#
# The result is an immutable sequence.

# %%
# creating tuple
number=tuple([1,2,3,4,5,6])
number
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
lst=list((1,2,3,4,5))
print(lst)
# Out:
# [1, 2, 3, 4, 5]

# %%
mixed_tuple=(99,"Hello World",3.14,True)
print(mixed_tuple)
# Out:
# (99, 'Hello World', 3.14, True)

# %%
## Accessing Tuple Element
number
# Out:
# (1, 2, 3)

# %%
print(number[2])
print(number[0:2])
print(number[-2::-1])## Third variable is step
# Out:
# 3
# (1, 2)
# (5, 4, 3, 2, 1)

# %%
## Tuples operations
concatenation_tuple =tuple=number + mixed_tuple 
print(concatenation_tuple)
# Out:
# (1, 2, 3, 4, 5, 6, 99, 'Hello World', 3.14, True)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
mixed_tuple*3
# Out:
# (99,
#  'Hello World',
#  3.14,
#  True,
#  99,
#  'Hello World',
#  3.14,
#  True,
#  99,
#  'Hello World',
#  3.14,
#  True)

# %%
number*3
## N number of times
# Out:
# (1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6)

# %%
## Immutalbe Nature of tuples
lst=[1,2,3,4,5]
print(lst)
lst[1]="Ayush"
print(lst)
## NOw for tuple 
number[1]="Ayush"
# Out:
# [1, 2, 3, 4, 5]
# [1, 'Ayush', 3, 4, 5]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 7
#       5 print(lst)
#       6 ## NOw for tuple
# ----> 7 number[1]="Ayush"
#
# TypeError: 'tuple' object does not support item assignment

# %%
## Tuple method
print(number.count(1))
print(number.index(3)) ## Here inside brac is the value
# Out:
# 1
# 2

# %%
## Packing and Unpacking tuple
## Packing
packed_tuple=1,"Hello ",3.14 ## by default if we declare like this ->tupel
print(packed_tuple)
# Out:
# (1, 'Hello ', 3.14)

# %%
## unpacking a tuple 
a,b,c=packed_tuple
print(a)
print(b)
print(c)
# Out:
# 1
# Hello
# 3.14

# %%
## Unpacking with *
numbers=(1,2,3,4,5,6)
first,*middle,last=numbers
print(first)
print(middle)
print(last)
# Out:
# 1
# [2, 3, 4, 5]
# 6

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
## Nested Tuple 
## Nested List
## Slicing operation can also be prerformed in nested list
lst=[[1,2,3,4],[6,7,8,9],[1,"hello ",3.24,"c"]]
lst[0][:3] ## firs ->index of list 2.[]->index inside index
# Out:
# [1, 2, 3]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
lst=[[1,2,3,4],[6,7,8,9],[1,"hello ",3.24,"c"]]
lst[0][:3]

# %%
## Nested tuple
nested_tuple=((1,2,3),("a","b","c"),(True,False))
## access the element inside a tuple
print(nested_tuple[0])
print(nested_tuple[1][2])
# Out:
# (1, 2, 3)
# c

# %%
# Iterating over nested tuples
for sub_tuple in nested_tuple:
    for item in sub_tuple:
        print(item,end="")
    print()
# Out:
# 123abcTrueFalse

# %% [markdown]
# 2. The end parameter in print()
#     The print() function has many optional parameters.
#
#     One important one is end.
#
#     end tells print() what to print after the item.

# %% [markdown]
# ![image.png](attachment:image.png)
