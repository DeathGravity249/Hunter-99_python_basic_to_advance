# %%
import array
arr=array.array('i',[1,2,3,4])
print(arr)
# Out:
# array('i', [1, 2, 3, 4])

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import math as m
print(m.sqrt(4))
# Out:
# 2.0

# %%
## random 
import random
print(random.randint(1,10)) # ->take value b/w 1-10
print(random.choice(['apple','banana','cherry']))## pick random choice
# Out:
# 8
# cherry

# %%
## File and Directory access
## to get current working directory cwd
import os
print(os.getcwd())
# Out:
# c:\Users\Death Gravity\OneDrive\Desktop\Hunter\Jupyter Notebook-1

# %%
os.mkdir('test_dir')

# %%
## High level operation on file
import shutil
shutil.copyfile('source.txt','destination')
# Out:
# 'destination'

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
## Data Serialzation
## JSON (javascript ofject notation )
import json
data={'name':'krish','age':25}
json_str=json.dumps(data)  
print(json_str)
print(type(json_str))

parsed_data=json.loads(json_str)
print(parsed_data)
print(type(parsed_data))
# Out:
# {"name": "krish", "age": 25}
# <class 'str'>
# {'name': 'krish', 'age': 25}
# <class 'dict'>

# %%
## This is AI response generated to distinguish the difference
import json

# Python dictionary
person = {"name": "Krish", "age": 25, "skills": ["Python", "AI"]}

# ✅ Serialize (dict → JSON string)
json_data = json.dumps(person)
print(json_data)         # {"name": "Krish", "age": 25, "skills": ["Python", "AI"]}
print(type(json_data))   # <class 'str'>

# ✅ Deserialize (JSON string → dict)
python_data = json.loads(json_data)
print(python_data)       # {'name': 'Krish', 'age': 25, 'skills': ['Python', 'AI']}
print(type(python_data)) # <class 'dict'>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
## csv ->Comma separated Values 
import csv
with open('example.csv',mode='w',newline='') as file:
    writer=csv.writer(file)
    writer.writerow(['name','age'])
    writer.writerow(['krish',32])
with open('example.csv',mode='r') as file:
    reader=csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['name', 'age']
# ['krish', '32']

# %%
from datetime import datetime,timedelta
now =datetime.now()
## datetime is a class that represents dates adn times
## timedelta represents a duration (difference between two dates /time)
print(now)
yesterday=now-timedelta(days=1)
print(yesterday)
# Out:
# 2025-08-03 01:10:41.000970
# 2025-08-02 01:10:41.000970

# %% [markdown]
# An object is a bundle of data (attributes) and behaviors (methods/functions) that work together.
#
# It’s an instance of a class.
#
# You can think of a class as a blueprint, and an object as a real thing created from that blueprint

# %%
## time
import time
print(time.time())
time.sleep(2)
print(time.time())

# %%
## REgular expression
import re

pattern=r'\d+'
text='There are 123 apples 456'
match=re.search(pattern,text)
print(match.group())
# Out:
# 123

# %% [markdown]
# ![image.png](attachment:image.png)
