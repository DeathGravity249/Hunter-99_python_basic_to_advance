# %%
# Arithmethic operator
a=29
b=3
add_result=a+b
sub_result=a-b
multi_result=a
div_result=a/b
floor_division =a//b
modulus_result=a%b
exponent_result=a**b
print(add_result)
print(sub_result)
print(div_result)
print(floor_division)
print(multi_result)
print(modulus_result)
# Out:
# 32
# 26
# 9.666666666666666
# 9
# 29
# 2

# %%
10/2
# Out:
# 5.0

# %%
31//2 # floor division only giving non decimal point
# Out:
# 15

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Comparisson
str1="Ayush"
str2="ayush"
str1!=str2
# Out:
# True
